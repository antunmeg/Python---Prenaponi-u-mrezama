# %% [markdown]
# DVOSTRUKI SILAZNI UDAR MUNJE
# I1 = 60 kA; tf = 4 us
# I2 = 20 kA; tf = 0,8 us

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# Podaci dvostrukog silaznog udara munje bez odvodnika prenapona

# load screen data
file_name = 'v_screen_silazni_bez_odvodnika.txt'
init_df_screen = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_screen = init_df_screen.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_screen.columns = init_df_screen.columns.str.strip()  # set columns without whitespaces
init_df_screen.set_index(init_df_screen.columns[0], inplace=True)  # set Time as index
init_df_screen.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_screen.columns[0:]))]
init_df_screen = init_df_screen/1000

# load core data
file_name = 'v_core_silazni_bez_odvodnika.txt'
init_df_core = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_core = init_df_core.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_core.columns = init_df_core.columns.str.strip()  # set columns without whitespaces
init_df_core.set_index(init_df_core.columns[0], inplace=True)  # set Time as index
init_df_core.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_core.columns[0:]))]
init_df_core = init_df_core/1000

# load cross data
file_name = 'v_cross_silazni_bez_odvodnika.txt'
init_df_cross = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross = init_df_cross.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross.columns = init_df_cross.columns.str.strip()  # set columns without whitespaces
init_df_cross.set_index(init_df_cross.columns[0], inplace=True)  # set Time as index
init_df_cross.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross.columns[0:]))]
init_df_cross = init_df_cross/1000

# %%
# Podaci dvostrukog silaznog udara munje uz odvodnik prenapona u gondoli

# load cross data
file_name = 'v_cross_silazni_odvodnik_gondola.txt'
init_df_cross_arrester = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross_arrester = init_df_cross_arrester.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross_arrester.columns = init_df_cross_arrester.columns.str.strip()  # set columns without whitespaces
init_df_cross_arrester.set_index(init_df_cross_arrester.columns[0], inplace=True)  # set Time as index
init_df_cross_arrester.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross_arrester.columns[0:]))]
init_df_cross_arrester = init_df_cross_arrester/1000

# %%
# define columns and X axis
all_voltages_labels = init_df_cross.columns
all_voltages_arrester_labels = init_df_cross_arrester.columns
x_time_axis1 = init_df_cross.index*1000
x_time_axis2 = init_df_cross_arrester.index*1000


fig = plt.figure()
axes = fig.add_axes([0, 0, 2, 1.5])
transf_voltage = init_df_cross[all_voltages_labels[9]]
transf_voltage_arrester = init_df_cross_arrester[all_voltages_arrester_labels[9]]

axes.plot(x_time_axis1, transf_voltage, 'r', lw=1, ls='-', marker='o', markersize=7, markevery=50, markerfacecolor='w')
axes.plot(x_time_axis2, transf_voltage_arrester, 'g', lw=1, ls='-', marker='o', markersize=7, markevery=50)
axes.set_xlabel('Time (ms)', fontsize=13)
axes.set_ylabel('Voltage (kV)', fontsize=13)
plt.title('Transformer overvoltage - zoomed')
axes.set_xlim([0.099, 0.12])
axes.legend(['Without SPD', 'SPD in nacelle'], fontsize=13)
axes.grid()

for tick in axes.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    

for tick in axes.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# C:\Users\Antun\Anaconda\lib\site-packages\IPython\core\events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\Antun\Anaconda\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# define columns and X axis
all_voltages_labels = init_df_cross.columns
all_voltages_arrester_labels = init_df_cross_arrester.columns
x_time_axis1 = init_df_cross.index*1000
x_time_axis2 = init_df_cross_arrester.index*1000


fig = plt.figure()
axes = fig.add_axes([0, 0, 2, 1.5])
transf_voltage = init_df_cross[all_voltages_labels[9]]
transf_voltage_arrester = init_df_cross_arrester[all_voltages_arrester_labels[9]]

axes.plot(x_time_axis1, transf_voltage, 'r')#, lw=1, ls='-', marker='o', markersize=7, markevery=50, markerfacecolor='w')
axes.plot(x_time_axis2, transf_voltage_arrester, 'g')#, lw=1, ls='-', marker='o', markersize=7, markevery=50)
axes.set_xlabel('Time (ms)', fontsize=13)
axes.set_ylabel('Voltage (kV)', fontsize=13)
plt.title('Transformer overvoltage')
axes.legend(['Without SPD', 'SPD in nacelle'], fontsize=13)
plt.xticks(np.arange(0, 1.1, step=0.1))
plt.yticks(np.arange(-300, 500, step=100))
axes.set_xlim([0, 1])
axes.grid()

for tick in axes.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    

for tick in axes.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)

# %%
# define columns and X axis
all_voltages_labels = init_df_cross.columns
all_voltages_arrester_labels = init_df_cross_arrester.columns
x_time_axis1 = init_df_cross.index*1000
x_time_axis2 = init_df_cross_arrester.index*1000


fig = plt.figure()
axes = fig.add_axes([0, 0, 2, 1.5])
transf_voltage = init_df_cross[all_voltages_labels[0]]
transf_voltage_arrester = init_df_cross_arrester[all_voltages_arrester_labels[0]]

axes.plot(x_time_axis1, transf_voltage, 'r', lw=1, ls='-', marker='o', markersize=7, markevery=50, markerfacecolor='w')
axes.plot(x_time_axis2, transf_voltage_arrester, 'g', lw=1, ls='-', marker='o', markersize=7, markevery=50)
axes.set_xlabel('Time (ms)', fontsize=13)
axes.set_ylabel('Voltage (kV)', fontsize=13)
plt.title('Power cable cross voltage at the tower bottom')
axes.legend(['Without SPD', 'SPD in nacelle'], fontsize=13)
axes.set_xlim([0.099, 0.12])
axes.grid()

for tick in axes.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    

for tick in axes.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)

# %%
# define columns and X axis
all_voltages_labels = init_df_cross.columns
all_voltages_arrester_labels = init_df_cross_arrester.columns
x_time_axis1 = init_df_cross.index*1000
x_time_axis2 = init_df_cross_arrester.index*1000


fig = plt.figure()
axes = fig.add_axes([0, 0, 2, 1.5])
transf_voltage = init_df_cross[all_voltages_labels[0]]
transf_voltage_arrester = init_df_cross_arrester[all_voltages_arrester_labels[0]]

axes.plot(x_time_axis1, transf_voltage, 'r')#, lw=1, ls='-', marker='o', markersize=7, markevery=50, markerfacecolor='w')
axes.plot(x_time_axis2, transf_voltage_arrester, 'g')#, lw=1, ls='-', marker='o', markersize=7, markevery=50)
axes.set_xlabel('Time (ms)', fontsize=13)
axes.set_ylabel('Voltage (kV)', fontsize=13)
plt.title('Power cable cross voltage at the tower bottom')
axes.legend(['Without SPD', 'SPD in nacelle'], fontsize=13)
axes.set_xlim([0, 1])
plt.xticks(np.arange(0, 1.1, step=0.1))
plt.yticks(np.arange(-700, 500, step=100))
axes.grid()

for tick in axes.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    

for tick in axes.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)

# %%
# plot max of each element
fig = plt.figure()
abs_ax = fig.add_axes([0, 0, 2, 1.5])
abs_maximums_screen = init_df_screen[(init_df_screen.index*1000>=0) & (init_df_screen.index*1000<0.45)].abs().max()
abs_maxiumum_core = init_df_core[(init_df_core.index*1000>=0) & (init_df_core.index*1000<0.45)].abs().max()
abs_maxiumum_cross = init_df_cross[(init_df_cross.index*1000>=0) & (init_df_cross.index*1000<0.45)].abs().max()

second_abs_maximums_screen = init_df_screen[(init_df_screen.index*1000>=0.45) & (init_df_screen.index*1000<1)].abs().max()
second_abs_maximums_core = init_df_core[(init_df_core.index*1000>=0.45) & (init_df_core.index*1000<1)].abs().max()
second_abs_maximums_cross = init_df_cross[(init_df_cross.index*1000>=0.45) & (init_df_cross.index*1000<1)].abs().max()

insulation_withstand = 10*[170]
xval_ = np.arange(1, len(abs_maximums_screen) + 1, 1)
abs_ax.set_xlabel("Tower section", fontsize=13)
abs_ax.set_ylabel("Voltage (kV)", fontsize=13)
abs_ax.plot(xval_, abs_maximums_screen, 'grey', lw=2, marker="s", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, second_abs_maximums_screen, 'grey', lw=2, ls='--', marker="s", markersize=9, markerfacecolor='w')

abs_ax.plot(xval_, abs_maxiumum_core, 'grey', lw=2, marker="D", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, second_abs_maximums_core, 'grey', lw=2, ls='--', marker="D", markersize=9, markerfacecolor='w')

abs_ax.plot(xval_, abs_maxiumum_cross, 'r', lw=2, marker="o", markersize=9)
abs_ax.plot(xval_, second_abs_maximums_cross, 'r', lw=2, ls='--', marker="o", markersize=9)

abs_ax.plot(xval_, insulation_withstand, 'k', lw=2, ls='-.', marker=11, markersize=9)

abs_ax.grid()

abs_ax.legend(['Shield voltage (First strike)', 'Shield voltage (Second strike)',
               'Conductor voltage (First strike)', 'Conductor voltage (Second strike)',
             'Insulation cross voltage (First strike)', 'Insulation cross voltage (Second strike)',
              'Insulation withstand voltage'], fontsize=13)

axes.set_xlim([1, 10])
plt.xticks(np.arange(1, 11, step=1))
plt.yticks(np.arange(0, 1000, step=100))

for tick in abs_ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
for tick in abs_ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
abs_ax2 = abs_ax.twiny()
abs_ax2.xaxis.set_ticks_position("bottom")
abs_ax2.xaxis.set_label_position("bottom")
abs_ax2.spines["bottom"].set_position(("axes", -0.05))
abs_ax2.set_frame_on(False)
abs_ax2.patch.set_visible(False)
new_tick_locations = np.array([0.045, 0.955])
abs_ax2.set_xticks(new_tick_locations)
abs_ax2.set_xticklabels(['Tower bottom', 'Tower Top (Transformer)'], fontsize=13)

plt.title('Dvostruki silazni udar')
# Out:
# Text(0.5, 1.0, 'Dvostruki silazni udar')

# %%
# load surge arrester power and energy data
file_name = 'snaga_energija_silazni_odvodnik_gondola.txt'
init_df_energy = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_energy = init_df_energy.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_energy.columns = init_df_energy.columns.str.strip()  # set columns without whitespaces
init_df_energy.set_index(init_df_energy.columns[0], inplace=True)  # set Time as index
init_df_energy.columns = [["Power (kW)", "Energy (kJ)"]]
init_df_energy = init_df_energy/1000

# %%
fig, ax1 = plt.subplots()
ax1 = fig.add_axes([0, 0, 2, 1.5])
x1 = init_df_energy.index*1000
ax1.plot(x1, 1000*init_df_energy[['Power (kW)']].values,  'blue', lw=2, label='Power dissipation')

ax1.set_xlabel("Time (ms)", fontsize=13)
ax1.set_ylabel("Power (W)", fontsize=13, color="blue")

for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    

for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)

ax1.grid()
ax1.set_ylim([0, 4e8])
plt.yticks(np.arange(0, 4.5e8, step=0.5e8))
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))

for label in ax1.get_yticklabels():
    label.set_color("blue")
    
ax1.yaxis.offsetText.set(size=15, color='blue')

ax2 = ax1.twinx()
ax2.plot(x1, init_df_energy[['Energy (kJ)']].values, 'r', lw=2, marker='s', markevery=8000, markersize=8, label='Apsorbed energy')

ax2.set_ylabel("Energy (kJ)", fontsize=13, color='r')  
ax2.tick_params(axis="y", labelsize=13)

for label in ax2.get_yticklabels():
    label.set_color("r")

plt.title('Surge arrester apsborbed energy and power dissipation')
# plt.legend(['Power', 'Energy'], fontsize=13)
ax2.set_xlim([0, 1])
plt.xticks(np.arange(0, 1.1, step=0.1))
plt.yticks(np.arange(0, 4.5, step=0.5))
ax2.set_ylim([0, 4])

lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
ax1.legend(lines, labels, loc=5, fontsize=13)

# %% [markdown]
# UZLAZNI UDAR MUNJE S VELIKOM STRMINOM
# Imax = 12 kA; tf = 1 us

# %%
# load screen data
file_name = 'v_screen_uzlazni_strmi_bez_odvodnika.txt'
init_df_screen = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_screen = init_df_screen.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_screen.columns = init_df_screen.columns.str.strip()  # set columns without whitespaces
init_df_screen.set_index(init_df_screen.columns[0], inplace=True)  # set Time as index
init_df_screen.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_screen.columns[0:]))]
init_df_screen = init_df_screen/1000

# load core data
file_name = 'v_core_uzlazni_strmi_bez_odvodnika.txt'
init_df_core = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_core = init_df_core.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_core.columns = init_df_core.columns.str.strip()  # set columns without whitespaces
init_df_core.set_index(init_df_core.columns[0], inplace=True)  # set Time as index
init_df_core.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_core.columns[0:]))]
init_df_core = init_df_core/1000

# load cross data
file_name = 'v_cross_uzlazni_strmi_bez_odvodnika.txt'
init_df_cross = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross = init_df_cross.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross.columns = init_df_cross.columns.str.strip()  # set columns without whitespaces
init_df_cross.set_index(init_df_cross.columns[0], inplace=True)  # set Time as index
init_df_cross.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross.columns[0:]))]
init_df_cross = init_df_cross/1000

# %%
# plot max of each element
fig = plt.figure()
abs_ax = fig.add_axes([0, 0, 2, 1.5])
abs_maximums_screen = init_df_screen[(init_df_screen.index*1000>=0) & (init_df_screen.index*1000<0.45)].abs().max()
abs_maxiumum_core = init_df_core[(init_df_core.index*1000>=0) & (init_df_core.index*1000<0.45)].abs().max()
abs_maxiumum_cross = init_df_cross[(init_df_cross.index*1000>=0) & (init_df_cross.index*1000<0.45)].abs().max()

insulation_withstand = 10*[170]
xval_ = np.arange(1, len(abs_maximums_screen) + 1, 1)
abs_ax.set_xlabel("Tower section", fontsize=13)
abs_ax.set_ylabel("Voltage (kV)", fontsize=13)
abs_ax.plot(xval_, abs_maximums_screen, 'grey', lw=2, marker="s", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, abs_maxiumum_core, 'grey', lw=2, marker="D", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, abs_maxiumum_cross, 'r', lw=2, marker="o", markersize=9)

abs_ax.plot(xval_, insulation_withstand, 'k', lw=2,  ls='-.', marker=11, markersize=9)

abs_ax.grid()

abs_ax.legend(['Shield voltage', 'Conductor voltage', 'Insulation cross voltage', 'Insulation withstand voltage'], fontsize=13)

axes.set_xlim([1, 10])
plt.xticks(np.arange(1, 11, step=1))
plt.yticks(np.arange(0, 350, step=50))

for tick in abs_ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
for tick in abs_ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
abs_ax2 = abs_ax.twiny()
abs_ax2.xaxis.set_ticks_position("bottom")
abs_ax2.xaxis.set_label_position("bottom")
abs_ax2.spines["bottom"].set_position(("axes", -0.05))
abs_ax2.set_frame_on(False)
abs_ax2.patch.set_visible(False)
new_tick_locations = np.array([.045, 0.955])
abs_ax2.set_xticks(new_tick_locations)
abs_ax2.set_xticklabels(['Tower bottom', 'Tower Top (Transformer)'], fontsize=13)

plt.title('Uzlazni udar s velikom strminom')
# Out:
# Text(0.5, 1.0, 'Uzlazni udar s velikom strminom')

# %%
# load cross data
file_name = 'v_cross_uzlazni_strmi_odvodnik_gondola.txt'
init_df_cross_arrester = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross_arrester = init_df_cross_arrester.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross_arrester.columns = init_df_cross_arrester.columns.str.strip()  # set columns without whitespaces
init_df_cross_arrester.set_index(init_df_cross_arrester.columns[0], inplace=True)  # set Time as index
init_df_cross_arrester.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross_arrester.columns[0:]))]
init_df_cross_arrester = init_df_cross_arrester/1000

# %%
# plot max of each element
fig = plt.figure()
abs_ax = fig.add_axes([0, 0, 2, 1.5])
abs_maximum_cross_arrester = init_df_cross_arrester.abs().max()

insulation_withstand = 10*[170]
xval_ = np.arange(1, len(abs_maximums_screen) + 1, 1)
abs_ax.set_xlabel("Tower section", fontsize=13)
abs_ax.set_ylabel("Voltage (kV)", fontsize=13)
abs_ax.plot(xval_, abs_maxiumum_cross, 'r', lw=2, marker="s", markersize=9)
abs_ax.plot(xval_, abs_maximum_cross_arrester, 'g', lw=2, marker="o", markersize=9, markerfacecolor='w')

abs_ax.plot(xval_, insulation_withstand, 'k', lw=2,  ls='-.', marker=11, markersize=9)

abs_ax.grid()

abs_ax.legend(['Insulation cross voltage without SPD', 'Insulation cross voltage with SPD in nacelle', 'Insulation withstand voltage'], fontsize=13)

axes.set_xlim([1, 10])
plt.xticks(np.arange(1, 11, step=1))
plt.yticks(np.arange(0, 300, step=50))

for tick in abs_ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
for tick in abs_ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
abs_ax2 = abs_ax.twiny()
abs_ax2.xaxis.set_ticks_position("bottom")
abs_ax2.xaxis.set_label_position("bottom")
abs_ax2.spines["bottom"].set_position(("axes", -0.05))
abs_ax2.set_frame_on(False)
abs_ax2.patch.set_visible(False)
new_tick_locations = np.array([.045, 0.955])
abs_ax2.set_xticks(new_tick_locations)
abs_ax2.set_xticklabels(['Tower bottom', 'Tower Top (Transformer)'], fontsize=13)

plt.title('Uzlazni udar s velikom strminom')
# Out:
# Text(0.5, 1.0, 'Uzlazni udar s velikom strminom')

# %%
# load cross data
file_name = 'v_cross_uzlazni_strmi_odvodnik_podnozje.txt'
init_df_cross_down_arrester = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross_down_arrester = init_df_cross_down_arrester.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross_down_arrester.columns = init_df_cross_down_arrester.columns.str.strip()  # set columns without whitespaces
init_df_cross_down_arrester.set_index(init_df_cross_down_arrester.columns[0], inplace=True)  # set Time as index
init_df_cross_down_arrester.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross_down_arrester.columns[0:]))]
init_df_cross_down_arrester = init_df_cross_down_arrester/1000

# %%
# plot max of each element
fig = plt.figure()
abs_ax = fig.add_axes([0, 0, 2, 1.5])
abs_maximum_cross_down_arrester = init_df_cross_down_arrester.abs().max()

insulation_withstand = 10*[170]
xval_ = np.arange(1, len(abs_maximums_screen) + 1, 1)
abs_ax.set_xlabel("Tower section", fontsize=13)
abs_ax.set_ylabel("Voltage (kV)", fontsize=13)
abs_ax.plot(xval_, abs_maxiumum_cross, 'r', lw=2, marker="s", markersize=9)
abs_ax.plot(xval_, abs_maximum_cross_down_arrester, 'g', lw=2, marker="o", markersize=9, markerfacecolor='w')

abs_ax.plot(xval_, insulation_withstand, 'k', lw=2,  ls='-.', marker=11, markersize=9)

abs_ax.grid()

abs_ax.legend(['Insulation cross voltage without SPD', 'Insulation cross voltage with SPD at tower bottom',
               'Insulation withstand voltage'], fontsize=13)

axes.set_xlim([1, 10])
plt.xticks(np.arange(1, 11, step=1))
plt.yticks(np.arange(0, 300, step=50))

for tick in abs_ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
for tick in abs_ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
abs_ax2 = abs_ax.twiny()
abs_ax2.xaxis.set_ticks_position("bottom")
abs_ax2.xaxis.set_label_position("bottom")
abs_ax2.spines["bottom"].set_position(("axes", -0.05))
abs_ax2.set_frame_on(False)
abs_ax2.patch.set_visible(False)
new_tick_locations = np.array([.045, 0.955])
abs_ax2.set_xticks(new_tick_locations)
abs_ax2.set_xticklabels(['Tower bottom', 'Tower Top (Transformer)'], fontsize=13)

plt.title('Uzlazni udar s velikom strminom')
# Out:
# Text(0.5, 1.0, 'Uzlazni udar s velikom strminom')

# %% [markdown]
# UZLAZNI UDAR MUNJE S BLAGOM STRMINOM Imax = 12 kA; tf = 8 us

# %%
# load screen data
file_name = 'v_screen_uzlazni_blagi_bez_odvodnika.txt'
init_df_screen = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_screen = init_df_screen.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_screen.columns = init_df_screen.columns.str.strip()  # set columns without whitespaces
init_df_screen.set_index(init_df_screen.columns[0], inplace=True)  # set Time as index
init_df_screen.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_screen.columns[0:]))]
init_df_screen = init_df_screen/1000

# load core data
file_name = 'v_core_uzlazni_blagi_bez_odvodnika.txt'
init_df_core = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_core = init_df_core.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_core.columns = init_df_core.columns.str.strip()  # set columns without whitespaces
init_df_core.set_index(init_df_core.columns[0], inplace=True)  # set Time as index
init_df_core.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_core.columns[0:]))]
init_df_core = init_df_core/1000

# load cross data
file_name = 'v_cross_uzlazni_blagi_bez_odvodnika.txt'
init_df_cross = pd.read_csv(file_name, sep='\t', header=1, decimal=',')
init_df_cross = init_df_cross.dropna(how='all').dropna(how='all', axis=1).reset_index(drop=True)  # drop empty columns / rows
init_df_cross.columns = init_df_cross.columns.str.strip()  # set columns without whitespaces
init_df_cross.set_index(init_df_cross.columns[0], inplace=True)  # set Time as index
init_df_cross.columns = ["Voltage_" + (str(i + 1)) +" (kV)" for i in np.arange(0, len(init_df_cross.columns[0:]))]
init_df_cross = init_df_cross/1000

# %%
# plot max of each element
fig = plt.figure()
abs_ax = fig.add_axes([0, 0, 2, 1.5])
abs_maximums_screen = init_df_screen.abs().max()
abs_maxiumum_core = init_df_core.abs().max()
abs_maxiumum_cross = init_df_cross.abs().max()

insulation_withstand = 10*[170]
xval_ = np.arange(1, len(abs_maximums_screen) + 1, 1)
abs_ax.set_xlabel("Tower section", fontsize=13)
abs_ax.set_ylabel("Voltage (kV)", fontsize=13)
abs_ax.plot(xval_, abs_maximums_screen, 'grey', lw=2, marker="s", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, abs_maxiumum_core, 'grey', lw=2, marker="D", markersize=9, markerfacecolor='w')
abs_ax.plot(xval_, abs_maxiumum_cross, 'r', lw=2, marker="o", markersize=9)

abs_ax.plot(xval_, insulation_withstand, 'k', lw=2,  ls='-.', marker=11, markersize=9)

abs_ax.grid()

abs_ax.legend(['Shield voltage', 'Conductor voltage', 'Insulation cross voltage', 'Insulation withstand voltage'], fontsize=13)

axes.set_xlim([1, 10])
plt.xticks(np.arange(1, 11, step=1))
plt.yticks(np.arange(0, 250, step=25))

for tick in abs_ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
for tick in abs_ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(13)
    
abs_ax2 = abs_ax.twiny()
abs_ax2.xaxis.set_ticks_position("bottom")
abs_ax2.xaxis.set_label_position("bottom")
abs_ax2.spines["bottom"].set_position(("axes", -0.05))
abs_ax2.set_frame_on(False)
abs_ax2.patch.set_visible(False)
new_tick_locations = np.array([.045, 0.955])
abs_ax2.set_xticks(new_tick_locations)
abs_ax2.set_xticklabels(['Tower bottom', 'Tower Top (Transformer)'], fontsize=13)

plt.title('Uzlazni udar s blagom strminom')

# plt.savefig('fig_x.eps', format='eps')
# plt.savefig('Fig_x', dpi=800)
# Out:
# Text(0.5, 1.0, 'Uzlazni udar s blagom strminom')
